# %%
# Dependencies and Setup
import pandas as pd
import datetime as dt

# File to Load 
load_stock_data = "autostock.csv"

# Read from CSV
auto_stock_df = pd.read_csv(load_stock_data)

auto_stock_df = auto_stock_df.drop(['Unnamed: 0'], axis=1)
auto_stock_df
# Out:
#       Symbol  Year  Month  Day     Open     High      Low    Close  Volume
# 0         TM  2005      2   25   71.640   72.224   71.556   72.104  249469
# 1         TM  2005      2   28   72.475   72.643   71.964   72.271  166169
# 2         TM  2005      3    1   72.337   72.708   72.290   72.597  273360
# 3         TM  2005      3    2   72.606   73.061   72.113   72.643  168321
# 4         TM  2005      3    3   72.661   72.959   72.215   72.439  276697
# ...      ...   ...    ...  ...      ...      ...      ...      ...     ...
# 22182   RACE  2017     11    6  117.190  117.750  116.460  117.250  473801
# 22183   RACE  2017     11    7  116.520  116.520  114.150  114.890  525050
# 22184   RACE  2017     11    8  113.440  113.440  110.480  112.800  719298
# 22185   RACE  2017     11    9  110.820  110.820  108.791  109.440  945188
# 22186   RACE  2017     11   10  109.780  109.990  109.070  109.560  525222
#
# [22187 rows x 9 columns]

# %%
auto_stock_df['Symbol'].unique()
# Out:
# array(['TM', 'TTM', 'HMC', 'GM', 'F', 'RACE'], dtype=object)

# %%
# File to Load 
load_sentiment_data = "UMICH-SOC37.csv"

# Read from CSV
auto_sentiment_df = pd.read_csv(load_sentiment_data)

auto_sentiment_df.head(50)

#Relative column is scalar value ("GOOD MINUS BAD PLUS 100")
# Out:
#           Date  Good time to Buy  Uncertain  Bad time to Buy  Relative
# 0   2021-03-31              54.0        6.0             40.0     114.0
# 1   2021-02-28              53.0        3.0             44.0     109.0
# 2   2021-01-31              56.0        5.0             39.0     117.0
# 3   2020-12-31              58.0        5.0             37.0     121.0
# 4   2020-11-30              57.0        7.0             36.0     121.0
# 5   2020-10-31              57.0        5.0             38.0     119.0
# 6   2020-09-30              61.0        5.0             34.0     127.0
# 7   2020-08-31              61.0        3.0             36.0     125.0
# 8   2020-07-31              61.0        2.0             37.0     124.0
# 9   2020-06-30              68.0        4.0             28.0     140.0
# 10  2020-05-31              64.0        3.0             33.0     131.0
# 11  2020-04-30              57.0        2.0             41.0     116.0
# ...

# %%
auto_sentiment_df.describe()
# Out:
#        Good time to Buy   Uncertain  Bad time to Buy    Relative
# count        519.000000  519.000000       519.000000  519.000000
# mean          61.235067    8.331407        30.433526  130.801541
# std            9.050835    3.411597         8.751112   17.474557
# min           29.000000    2.000000        13.000000   68.000000
# 25%           59.000000    6.000000        25.000000  124.000000
# 50%           63.000000    8.000000        29.000000  134.000000
# 75%           67.000000   10.000000        35.000000  141.500000
# max           81.000000   22.000000        61.000000  165.000000

# %%
# File to Load 
load_sentiment_detail = "UMICH-SOC38.csv"

# Read from CSV
sentiment_detail_df = pd.read_csv(load_sentiment_detail)

sentiment_detail_df.head(50)

#Relative: prices column (%LOW PRICES - %HIGH PRICES)
# Out:
#           Date  Good Time<br>Prices are Low  \
# 0   2021-03-31                         26.0
# 1   2021-02-28                         28.0
# 2   2021-01-31                         32.0
# 3   2020-12-31                         35.0
# 4   2020-11-30                         33.0
# 5   2020-10-31                         35.0
# 6   2020-09-30                         37.0
# 7   2020-08-31                         40.0
# 8   2020-07-31                         43.0
# 9   2020-06-30                         49.0
# 10  2020-05-31                         52.0
# 11  2020-04-30                         42.0
# 12  2020-03-31                         26.0
# 13  2020-02-29                         23.0
# 14  2020-01-31                         21.0
# 15  2019-12-31                         25.0
# 16  2019-11-30                         28.0
# 17  2019-10-31                         24.0
# 18  2019-09-30                         25.0
# 19  2019-08-31                         24.0
# ...

# %%
sentiment_detail_df.describe()
# Out:
#        Good Time<br>Prices are Low  Good Time<br>Prices will increase  \
# count                   518.000000                         518.000000
# mean                     30.484556                           8.208494
# std                       9.882616                           6.387773
# min                       4.000000                           0.000000
# 25%                      25.000000                           4.000000
# 50%                      29.000000                           6.000000
# 75%                      36.000000                          11.000000
# max                      64.000000                          43.000000
#
#        Good Time<br>Interest rates low  Good Time<br>Rising interest rates  \
# count                       518.000000                          518.000000
# mean                         20.832046                            1.631274
# std                          11.911049                            1.418702
# ...

# %%
sentiment_detail_df.dtypes
# Out:
# Date                                   object
# Good Time<br>Prices are Low           float64
# Good Time<br>Prices will increase     float64
# Good Time<br>Interest rates low       float64
# Good Time<br>Rising interest rates    float64
# Good Time<br>Times good               float64
# Good Time<br>Fuel Efficiency          float64
# Bad Time<br>Prices High               float64
# Bad Time<br>Interest rates high       float64
# Bad Time<br>Can't Afford              float64
# Bad Time<br>Uncertain Future          float64
# Bad Time<br>Gas Prices                float64
# Bad Time<br>Poor Selection            float64
# Relative: prices                      float64
# Relative: rates                       float64
# dtype: object

# %%
# Caste Start_Time into datetime data type
#sentiment_detail_df["DateTime"] = sentiment_detail_df["Date"]
sentiment_detail_df = sentiment_detail_df.astype({'Date': 'datetime64'})
sentiment_detail_df
# Out:
#           Date  Good Time<br>Prices are Low  \
# 0   2021-03-31                         26.0
# 1   2021-02-28                         28.0
# 2   2021-01-31                         32.0
# 3   2020-12-31                         35.0
# 4   2020-11-30                         33.0
# ..         ...                          ...
# 513 1978-06-30                          7.0
# 514 1978-05-31                          6.0
# 515 1978-04-30                          7.0
# 516 1978-03-31                         12.0
# 517 1978-02-28                         10.0
#
#      Good Time<br>Prices will increase  Good Time<br>Interest rates low  \
# 0                                  5.0                             18.0
# 1                                  3.0                             20.0
# 2                                  2.0                             20.0
# 3                                  1.0                             24.0
# ...

# %%
sentiment_detail_df['Year'] = sentiment_detail_df['Date'].dt.year
sentiment_detail_df['Month'] = sentiment_detail_df['Date'].dt.month
sentiment_detail_df
# Out:
#           Date  Good Time<br>Prices are Low  \
# 0   2021-03-31                         26.0
# 1   2021-02-28                         28.0
# 2   2021-01-31                         32.0
# 3   2020-12-31                         35.0
# 4   2020-11-30                         33.0
# ..         ...                          ...
# 513 1978-06-30                          7.0
# 514 1978-05-31                          6.0
# 515 1978-04-30                          7.0
# 516 1978-03-31                         12.0
# 517 1978-02-28                         10.0
#
#      Good Time<br>Prices will increase  Good Time<br>Interest rates low  \
# 0                                  5.0                             18.0
# 1                                  3.0                             20.0
# 2                                  2.0                             20.0
# 3                                  1.0                             24.0
# ...

# %%
# rename columns
sentiment_detail_df.rename(columns={
    'Good Time<br>Prices are Low': "Good_Time_Prices_Low",
    'Good Time<br>Prices will increase': "Good_Time_Prices_will_increase",
    'Good Time<br>Interest rates low': "Good_Time_Interest_rates_low",
    'Good Time<br>Rising interest rates': "Good_Time_Rising_interest_rates",
    'Good Time<br>Times good': "Good_Time_Times_good",
    'Good Time<br>Fuel Efficiency': "Good_Time_Fuel_Efficiency",
    'Bad Time<br>Prices High': "Bad_Time_Prices_High",
    'Bad Time<br>Interest rates high': "Bad_Time_Interest_rates_high",
    'Bad Time<br>Can\'t Afford': "Bad_Time_Cannot_Afford",
    'Bad Time<br>Uncertain Future': "Bad_Time_Uncertain_Future",
    'Bad Time<br>Gas Prices': "Bad_Time_Gas_Prices",
    'Bad Time<br>Poor Selection': "Bad_Time_Poor_Selection",
    'Relative: prices': "Relative_prices",
    'Relative: rates': "Relative_rates"
}, inplace=True)

sentiment_detail_df
# Out:
#           Date  Good_Time_Prices_Low  Good_Time_Prices_will_increase  \
# 0   2021-03-31                  26.0                             5.0
# 1   2021-02-28                  28.0                             3.0
# 2   2021-01-31                  32.0                             2.0
# 3   2020-12-31                  35.0                             1.0
# 4   2020-11-30                  33.0                             2.0
# ..         ...                   ...                             ...
# 513 1978-06-30                   7.0                            39.0
# 514 1978-05-31                   6.0                            33.0
# 515 1978-04-30                   7.0                            36.0
# 516 1978-03-31                  12.0                            34.0
# 517 1978-02-28                  10.0                            25.0
#
#      Good_Time_Interest_rates_low  Good_Time_Rising_interest_rates  \
# 0                            18.0                              0.0
# ...

# %%
# Caste Start_Time into datetime data type
#sentiment_detail_df["DateTime"] = sentiment_detail_df["Date"]
auto_sentiment_df = auto_sentiment_df.astype({'Date': 'datetime64'})
auto_sentiment_df
# Out:
#           Date  Good time to Buy  Uncertain  Bad time to Buy  Relative
# 0   2021-03-31              54.0        6.0             40.0     114.0
# 1   2021-02-28              53.0        3.0             44.0     109.0
# 2   2021-01-31              56.0        5.0             39.0     117.0
# 3   2020-12-31              58.0        5.0             37.0     121.0
# 4   2020-11-30              57.0        7.0             36.0     121.0
# ..         ...               ...        ...              ...       ...
# 514 1978-05-31              50.0       18.0             32.0     118.0
# 515 1978-04-30              51.0       17.0             32.0     119.0
# 516 1978-03-31              55.0       13.0             32.0     123.0
# 517 1978-02-28              45.0       22.0             33.0     112.0
# 518 1978-01-31              48.0       17.0             35.0     113.0
#
# [519 rows x 5 columns]

# %%
auto_sentiment_df['Year'] = auto_sentiment_df['Date'].dt.year
auto_sentiment_df['Month'] = auto_sentiment_df['Date'].dt.month
auto_sentiment_df
# Out:
#           Date  Good time to Buy  Uncertain  Bad time to Buy  Relative  Year  \
# 0   2021-03-31              54.0        6.0             40.0     114.0  2021
# 1   2021-02-28              53.0        3.0             44.0     109.0  2021
# 2   2021-01-31              56.0        5.0             39.0     117.0  2021
# 3   2020-12-31              58.0        5.0             37.0     121.0  2020
# 4   2020-11-30              57.0        7.0             36.0     121.0  2020
# ..         ...               ...        ...              ...       ...   ...
# 514 1978-05-31              50.0       18.0             32.0     118.0  1978
# 515 1978-04-30              51.0       17.0             32.0     119.0  1978
# 516 1978-03-31              55.0       13.0             32.0     123.0  1978
# 517 1978-02-28              45.0       22.0             33.0     112.0  1978
# 518 1978-01-31              48.0       17.0             35.0     113.0  1978
#
#      Month
# 0        3
# 1        2
# ...

# %%
# rename columns
auto_sentiment_df.rename(columns={
    'Good time to Buy': "Good_time_to_Buy",
    'Bad time to Buy': "Bad_time_to_Buy"
    }, inplace=True)

auto_sentiment_df
# Out:
#           Date  Good_time_to_Buy  Uncertain  Bad_time_to_Buy  Relative  Year  \
# 0   2021-03-31              54.0        6.0             40.0     114.0  2021
# 1   2021-02-28              53.0        3.0             44.0     109.0  2021
# 2   2021-01-31              56.0        5.0             39.0     117.0  2021
# 3   2020-12-31              58.0        5.0             37.0     121.0  2020
# 4   2020-11-30              57.0        7.0             36.0     121.0  2020
# ..         ...               ...        ...              ...       ...   ...
# 514 1978-05-31              50.0       18.0             32.0     118.0  1978
# 515 1978-04-30              51.0       17.0             32.0     119.0  1978
# 516 1978-03-31              55.0       13.0             32.0     123.0  1978
# 517 1978-02-28              45.0       22.0             33.0     112.0  1978
# 518 1978-01-31              48.0       17.0             35.0     113.0  1978
#
#      Month
# 0        3
# 1        2
# ...

# %%
combined_basic_df = auto_stock_df.merge(auto_sentiment_df, on=['Month','Year'])
combined_basic_df
# Out:
#       Symbol  Year  Month  Day    Open    High     Low   Close    Volume  \
# 0         TM  2005      2   25  71.640  72.224  71.556  72.104    249469
# 1         TM  2005      2   28  72.475  72.643  71.964  72.271    166169
# 2        TTM  2005      2   25  10.270  10.318  10.156  10.175    167534
# 3        TTM  2005      2   28  10.318  10.414  10.127  10.347    386313
# 4        HMC  2005      2   25  25.346  25.576  25.346  25.566    115828
# ...      ...   ...    ...  ...     ...     ...     ...     ...       ...
# 21930      F  2005      1   25  10.300  10.575  10.300  10.426  14696545
# 21931      F  2005      1   26  10.463  10.528  10.377  10.522   8827671
# 21932      F  2005      1   27  10.449  10.488  10.377  10.395   7987342
# 21933      F  2005      1   28  10.362  10.443  10.275  10.354  11752334
# 21934      F  2005      1   31  10.443  10.473  10.332  10.377   8853689
#
#             Date  Good_time_to_Buy  Uncertain  Bad_time_to_Buy  Relative
# ...

# %%
combined_df = auto_stock_df.merge(sentiment_detail_df, on=['Month','Year'])
combined_df
# Out:
#       Symbol  Year  Month  Day    Open    High     Low   Close    Volume  \
# 0         TM  2005      2   25  71.640  72.224  71.556  72.104    249469
# 1         TM  2005      2   28  72.475  72.643  71.964  72.271    166169
# 2        TTM  2005      2   25  10.270  10.318  10.156  10.175    167534
# 3        TTM  2005      2   28  10.318  10.414  10.127  10.347    386313
# 4        HMC  2005      2   25  25.346  25.576  25.346  25.566    115828
# ...      ...   ...    ...  ...     ...     ...     ...     ...       ...
# 21909      F  2005      1   25  10.300  10.575  10.300  10.426  14696545
# 21910      F  2005      1   26  10.463  10.528  10.377  10.522   8827671
# 21911      F  2005      1   27  10.449  10.488  10.377  10.395   7987342
# 21912      F  2005      1   28  10.362  10.443  10.275  10.354  11752334
# 21913      F  2005      1   31  10.443  10.473  10.332  10.377   8853689
#
#             Date  ...  Good_Time_Times_good  Good_Time_Fuel_Efficiency  \
# ...

# %%
null_check = combined_df.isna
null_check
# Out:
# <bound method DataFrame.isna of       Symbol  Year  Month  Day    Open    High     Low   Close    Volume  \
# 0         TM  2005      2   25  71.640  72.224  71.556  72.104    249469
# 1         TM  2005      2   28  72.475  72.643  71.964  72.271    166169
# 2        TTM  2005      2   25  10.270  10.318  10.156  10.175    167534
# 3        TTM  2005      2   28  10.318  10.414  10.127  10.347    386313
# 4        HMC  2005      2   25  25.346  25.576  25.346  25.566    115828
# ...      ...   ...    ...  ...     ...     ...     ...     ...       ...
# 21909      F  2005      1   25  10.300  10.575  10.300  10.426  14696545
# 21910      F  2005      1   26  10.463  10.528  10.377  10.522   8827671
# 21911      F  2005      1   27  10.449  10.488  10.377  10.395   7987342
# 21912      F  2005      1   28  10.362  10.443  10.275  10.354  11752334
# 21913      F  2005      1   31  10.443  10.473  10.332  10.377   8853689
#
# ...

# %%
combined_df.to_csv("StocksAndSentiment.csv")

# %%
combined_basic_df.to_csv("StocksAndSentiment_basic.csv")

# %%
# Mongo DB dependencies
import pymongo

# The default port used by MongoDB is 27017
conn = 'mongodb+srv://aUserAccount:aSecurePassword@cluster0.6oig2.mongodb.net/testclient'
client = pymongo.MongoClient(conn,ssl=True,ssl_cert_reqs='CERT_NONE')

# Define the accident database in Mongo
db = client.stocks_and_sentiments

# Define accidents Collection
stocks = db.stocks

# %%
# Iterature through final Portland dataframe and create Mongo accident collection
for index, row in combined_df.iterrows():
    stock_data={    
        "Symbol" : row['Symbol'],
        "Year" : row['Year'],
        "Month" : row['Month'],
        "Day" : row['Day'],
        "Open" : row['Open'],
        "High" : row['High'],
        "Low" : row['Low'],
        "Close" : row['Close'],
        "Volume" : row['Volume'],
        "Good_Time_Prices_Low": row['Good_Time_Prices_Low'],
        "Good_Time_Prices_will_increase": row['Good_Time_Prices_will_increase'],
        "Good_Time_Interest_rates_low": row['Good_Time_Interest_rates_low'],
        "Good_Time_Rising_interest_rates": row['Good_Time_Rising_interest_rates'],
        "Good_Time_Times_good": row['Good_Time_Times_good'],
        "Good_Time_Fuel_Efficiency": row['Good_Time_Fuel_Efficiency'],
        "Bad_Time_Prices_High": row['Bad_Time_Prices_High'],
        "Bad_Time_Interest_rates_high": row['Bad_Time_Interest_rates_high'],
        "Bad_Time_Cannot_Afford": row['Bad_Time_Cannot_Afford'],
        "Bad_Time_Uncertain_Future": row['Bad_Time_Uncertain_Future'],
        "Bad_Time_Gas_Prices": row['Bad_Time_Gas_Prices'],
        "Bad_Time_Poor_Selection": row['Bad_Time_Poor_Selection']
        #"Relative_prices",
        #"Relative_rates"        
    }
    
    #import into MongoDB         
    stocks.insert_one(stock_data)
